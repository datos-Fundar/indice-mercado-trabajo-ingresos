# %%
import requests
from bs4 import BeautifulSoup
import csv

# Make an HTTP GET request to the website
url = "https://www.onetonline.org/link/summary/35-3041.00"
response = requests.get(url)

# Parse the HTML content of the website with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <title>35-3041.00 - Food Servers, Nonrestaurant</title>
# <link href="https://www.onetcenter.org/rss/whatsnew.xml" rel="alternate" type="application/rss+xml"/>
# <link href="/apple-touch-icon.png?v=20201126" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon-32x32.png?v=20201126" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-16x16.png?v=20201126" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/site.webmanifest?v=20201126" rel="manifest"/>
# <link href="/favicon.ico?v=20201126" rel="shortcut icon"/>
# <meta content="#2d89ef" name="msapplication-TileColor"/>
# <meta content="#004488" name="theme-color"/>
# <meta content="summary_large_image" name="twitter:card"/>
# ...

# %%
task_items = soup.find_all('li', class_='')

# %%
task_items
# Out:
# [<li><a class="dropdown-item" href="/link/custom/35-3041.00">Custom</a></li>,
#  <li><a class="dropdown-item mnmpopup" data-bs-target="#mnmModal" data-cookie="OLwarnmnm" data-toggle="linkwarn" data-track="/shared/track/mr_mnm" href="https://www.mynextmove.org/profile/summary/35-3041.00">Easy Read</a></li>,
#  <li><a class="dropdown-item vetspopup" data-bs-target="#vetsModal" data-cookie="OLwarnvets" data-toggle="linkwarn" data-track="/shared/track/mr_vets" href="https://www.mynextmove.org/vets/profile/summary/35-3041.00">Veterans</a></li>,
#  <li><a class="dropdown-item mpppopup" data-bs-target="#mppModal" data-cookie="OLwarnmpp" data-toggle="linkwarn" data-track="/shared/track/mr_mpp" href="https://www.miproximopaso.org/profile/summary/35-3041.00">Español</a></li>,
#  <li><a class="dropdown-item" href="#Tasks">Tasks</a></li>,
#  <li><a class="dropdown-item" href="#TechnologySkills">Technology Skills</a></li>,
# ...

# %%
item
# Out:
# <li><a class="dropdown-item" href="/link/custom/35-3041.00">Custom</a></li>

# %%
tasks = []
task_items = soup.find_all('li', class_='')
for item in task_items:
    task = item.find('div', class_='order-2')

    if task is not None:
        print(task)
        #.text.strip()
        #tasks.append(task)
# Out:
# <div class="order-2 flex-grow-1">Place food servings on plates or trays according to orders or instructions.</div>
# <div class="order-2 flex-grow-1">Clean or sterilize dishes, kitchen utensils, equipment, or facilities.</div>
# <div class="order-2 flex-grow-1">Monitor food distribution, ensuring that meals are delivered to the correct recipients and that guidelines, such as those for special diets, are followed.</div>
# <div class="order-2 flex-grow-1">Examine trays to ensure that they contain required items.</div>
# <div class="order-2 flex-grow-1">Load trays with accessories, such as eating utensils, napkins, or condiments.</div>
# <div class="order-2 flex-grow-1"><b>Data base user interface and query software</b> — CBORD Nutrition Service Suite; Picis CareSuite</div>
# <div class="order-2 flex-grow-1"><b>Enterprise resource planning ERP software</b> — Capital Codeworks MenuMax</div>
# ...

# %%
tasks_section = soup.find('div', {'id': 'tasks'})

# %%
tasks_section = soup.find('section', {'id': 'taskList'})

# %%
tasks_section

# %%
# Extract the task list
task_list = []
for li in tasks_section.find_all('li'):
    task_list.append(li.text.strip())

# Export the task list to a CSV file
with open('tasks.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    for task in task_list:
        writer.writerow([task])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Untitled-1.ipynb Cell 3 in <cell line: 3>()
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W2sdW50aXRsZWQ%3D?line=0'>1</a> # Extract the task list
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W2sdW50aXRsZWQ%3D?line=1'>2</a> task_list = []
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W2sdW50aXRsZWQ%3D?line=2'>3</a> for li in tasks_section.find_all('li'):
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W2sdW50aXRsZWQ%3D?line=3'>4</a>     task_list.append(li.text.strip())
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W2sdW50aXRsZWQ%3D?line=5'>6</a> # Export the task list to a CSV file
#
# AttributeError: 'NoneType' object has no attribute 'find_all'
